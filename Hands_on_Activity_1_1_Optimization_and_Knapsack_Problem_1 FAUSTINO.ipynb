# %% [markdown]
# # Hands-on Activity 1.1 | Optimization and Knapsack Problem

# %% [markdown]
# #### Objective(s):
#
# This activity aims to demonstrate how to apply  greedy and brute force algorithms to solve optimization problems

# %% [markdown]
# #### Intended Learning Outcomes (ILOs):
# * Demonstrate how to solve knapsacks problems using greedy algorithm
# * Demonstrate how to  solve knapsacks problems using brute force algorithm

# %% [markdown]
# #### Resources:
# * Jupyter Notebook

# %% [markdown]
# #### Procedures:

# %% [markdown]
# 1. Create a Food class that defines the following:
# * name of the food
# * value of the food
# * calories of the food
#
# 2. Create the following methods inside the Food class:
# * A method that returns the value of the food
# * A method that returns the cost of the food
# * A method that calculates the density of the food (Value / Cost)
# * A method that returns a string to display the name, value and calories of the food

# %%
class Food(object):
    def __init__(self, n, v, w, c):
        # Make the variables private
        self.name = n
        self.value = v
        self.calories = w
        self.carbohydrates = c
    def getValue(self):
        return self.value
    def getCost(self):
        return self.calories
    def getcarbohydrate(self):
        return self.carbohydrates
    def density(self):
        return self.getValue()/self.getCost()
   
    def __str__(self):
        return self.name + ': <' + str(self.value)+ ', ' + str(self.calories) + '>'

# %% [markdown]
# 3. Create a buildMenu method that builds the name, value and calories of the food

# %%
def buildMenu(names, values, calories, carbohydrates):
    menu = []
    for i in range(len(values)):
     menu.append(Food(names[i], values[i], calories[i], carbohydrates[i]))
    return menu

# %% [markdown]
# 4. Create a method greedy to return total value and cost of added food based on the desired maximum cost

# %%
def greedy(items, maxCost, keyFunction):
    """Assumes items a list, maxCost >= 0,         keyFunction maps elements of items to numbers"""
    itemsCopy = sorted(items, key = keyFunction,
                       reverse = True)
    result = []
    totalValue, totalCost = 0.0, 0.0
    for i in range(len(itemsCopy)):
        if (totalCost+itemsCopy[i].getCost()) <= maxCost:
            result.append(itemsCopy[i])
            totalCost += itemsCopy[i].getCost()
            totalValue += itemsCopy[i].getValue()
    return (result, totalValue)

# %% [markdown]
# 5. Create a testGreedy method to test the greedy method

# %%
def testGreedy(items, constraint, keyFunction):
    taken, val = greedy(items, constraint, keyFunction)
    print('Total value of items taken =', val)
    for item in taken:
        print('   ', item)

# %%
def testGreedys(foods, maxUnits):
    print('Use greedy by value to allocate', maxUnits,          'calories')
    testGreedy(foods, maxUnits, Food.getValue)
    print('\nUse greedy by cost to allocate', maxUnits,          'calories')
    testGreedy(foods, maxUnits, lambda x: 1/Food.getcost(x))
    print('\nUse greedy by density to allocate', maxUnits,          'calories')
    testGreedy(foods, maxUnits, Food.density)
    print('\nUse greedy by carbohydrates to allocate', maxUnits,          'calories')
    testGreedy(foods, maxUnits, Food.getcarbohydrates)

# %% [markdown]
# 6. Create arrays of food name, values and calories
# 7. Call the buildMenu to create menu for food
# 8. Use testGreedys method to pick food according to the desired calories

# %%
names = ['wine', 'beer', 'pizza', 'burger', 'fries','cola', 'apple', 'donut', 'cake']
values = [89,90,95,100,90,79,50,10]
calories = [123,154,258,354,365,150,95,195]
carbohydrates = [4, 13, 36, 45, 48, 39, 14, 25]
foods = buildMenu(names, values, calories, carbohydrates)
testGreedys(foods, 2000)
# Out:
# Use greedy by value to allocate 2000 calories
# Total value of items taken = 603.0
#     burger: <100, 354>
#     pizza: <95, 258>
#     beer: <90, 154>
#     fries: <90, 365>
#     wine: <89, 123>
#     cola: <79, 150>
#     apple: <50, 95>
#     donut: <10, 195>
#
# Use greedy by cost to allocate 2000 calories
# Total value of items taken = 603.0
#     apple: <50, 95>
#     wine: <89, 123>
#     cola: <79, 150>
#     beer: <90, 154>
#     donut: <10, 195>
#     pizza: <95, 258>
#     burger: <100, 354>
#     fries: <90, 365>
#
# Use greedy by density to allocate 2000 calories
# Total value of items taken = 603.0
#     wine: <89, 123>
#     beer: <90, 154>
#     cola: <79, 150>
#     apple: <50, 95>
#     pizza: <95, 258>
#     burger: <100, 354>
#     fries: <90, 365>
#     donut: <10, 195>
#
# Use greedy by carbohydrates to allocate 2000 calories
# Total value of items taken = 603.0
#     wine: <89, 123>
#     beer: <90, 154>
#     cola: <79, 150>
#     apple: <50, 95>
# ...

# %% [markdown]
# Task 1: Change the maxUnits to 100

# %%
names = ['wine', 'beer', 'pizza', 'burger', 'fries','cola', 'apple', 'donut', 'cake']
values = [89,90,95,100,90,79,50,10]
calories = [123,154,258,354,365,150,95,195]
carbohydrates = [4, 13, 36, 45, 48, 39, 14, 25] 
foods = buildMenu(names, values, calories, carbohydrates)
testGreedys(foods, 100)
# Out:
# Use greedy by value to allocate 100 calories
# Total value of items taken = 50.0
#     apple: <50, 95>
#
# Use greedy by cost to allocate 100 calories
# Total value of items taken = 50.0
#     apple: <50, 95>
#
# Use greedy by density to allocate 100 calories
# Total value of items taken = 50.0
#     apple: <50, 95>
#
# Use greedy by carbohydrates to allocate 100 calories
# Total value of items taken = 50.0
#     apple: <50, 95>

# %% [markdown]
# Task 2: Modify codes to add additional weight (criterion) to select food items.

# %%
names = ['wine', 'beer', 'pizza', 'burger', 'fries','cola', 'apple', 'donut', 'cake']
values = [89,90,95,100,90,79,50,10]
calories = [123,154,258,354,365,150,95,195]
carbohydrates = [4, 13, 36, 45, 48, 39, 14, 25] 
foods = buildMenu(names, values, calories, carbohydrates)
testGreedys(foods, 2000)
# Out:
# Use greedy by value to allocate 2000 calories
# Total value of items taken = 603.0
#     burger: <100, 354>
#     pizza: <95, 258>
#     beer: <90, 154>
#     fries: <90, 365>
#     wine: <89, 123>
#     cola: <79, 150>
#     apple: <50, 95>
#     donut: <10, 195>
#
# Use greedy by cost to allocate 2000 calories
# Total value of items taken = 603.0
#     apple: <50, 95>
#     wine: <89, 123>
#     cola: <79, 150>
#     beer: <90, 154>
#     donut: <10, 195>
#     pizza: <95, 258>
#     burger: <100, 354>
#     fries: <90, 365>
#
# Use greedy by density to allocate 2000 calories
# Total value of items taken = 603.0
#     wine: <89, 123>
#     beer: <90, 154>
#     cola: <79, 150>
#     apple: <50, 95>
#     pizza: <95, 258>
#     burger: <100, 354>
#     fries: <90, 365>
#     donut: <10, 195>
#
# Use greedy by carbohydrates to allocate 2000 calories
# Total value of items taken = 603.0
#     wine: <89, 123>
#     beer: <90, 154>
#     cola: <79, 150>
#     apple: <50, 95>
# ...

# %% [markdown]
# Task 3: Test your modified code to test the greedy algorithm to select food items with your additional weight.

# %%
def testGreedy(items, constraint, keyFunction):
    taken, val = greedy(items, constraint, keyFunction)
    print('Total value of items taken =', val)
    for item in taken:
        print('   ', item)
def testGreedys(foods, maxUnits):
    print('Use greedy by value to allocate', maxUnits,          'calories')
    testGreedy(foods, maxUnits, Food.getValue)
    print('\nUse greedy by cost to allocate', maxUnits,          'calories')
    testGreedy(foods, maxUnits, lambda x: 1/Food.getCost(x))
    print('\nUse greedy by density to allocate', maxUnits,          'calories')
    testGreedy(foods, maxUnits, Food.density)
    print('\nUse greedy by carbohydrates to allocate', maxUnits,          'calories')
    testGreedy(foods, maxUnits, Food.density)
    names = ['wine', 'beer', 'pizza', 'burger', 'fries','cola', 'apple', 'donut', 'cake']
values = [89,90,95,100,90,79,50,10]
calories = [123,154,258,354,365,150,95,195]
carbohydrates = [4, 13, 36, 45, 48, 39, 14, 25] 
foods = buildMenu(names, values, calories, carbohydrates)
testGreedys(foods, 2000)
# Out:
# Use greedy by value to allocate 2000 calories
# Total value of items taken = 603.0
#     burger: <100, 354>
#     pizza: <95, 258>
#     beer: <90, 154>
#     fries: <90, 365>
#     wine: <89, 123>
#     cola: <79, 150>
#     apple: <50, 95>
#     donut: <10, 195>
#
# Use greedy by cost to allocate 2000 calories
# Total value of items taken = 603.0
#     apple: <50, 95>
#     wine: <89, 123>
#     cola: <79, 150>
#     beer: <90, 154>
#     donut: <10, 195>
#     pizza: <95, 258>
#     burger: <100, 354>
#     fries: <90, 365>
#
# Use greedy by density to allocate 2000 calories
# Total value of items taken = 603.0
#     wine: <89, 123>
#     beer: <90, 154>
#     cola: <79, 150>
#     apple: <50, 95>
#     pizza: <95, 258>
#     burger: <100, 354>
#     fries: <90, 365>
#     donut: <10, 195>
#
# Use greedy by carbohydrates to allocate 2000 calories
# Total value of items taken = 603.0
#     wine: <89, 123>
#     beer: <90, 154>
#     cola: <79, 150>
#     apple: <50, 95>
# ...

# %% [markdown]
# 9. Create method to use  Bruteforce algorithm instead of greedy algorithm

# %%
def maxVal(toConsider, avail):
    """Assumes toConsider a list of items, avail a weight
       Returns a tuple of the total value of a solution to the
         0/1 knapsack problem and the items of that solution"""
    if toConsider == [] or avail == 0:
        result = (0, ())
    elif toConsider[0].getCost() > avail:
        #Explore right branch only
        result = maxVal(toConsider[1:], avail)
    else:
        nextItem = toConsider[0]
        #Explore left branch
        withVal, withToTake = maxVal(toConsider[1:],
                                     avail - nextItem.getCost())
        withVal += nextItem.getValue()
        #Explore right branch
        withoutVal, withoutToTake = maxVal(toConsider[1:], avail)
        #Choose better branch
        if withVal > withoutVal:
            result = (withVal, withToTake + (nextItem,))
        else:
            result = (withoutVal, withoutToTake)
    return result

# %%
def testMaxVal(foods, maxUnits, printItems = True):
    print('Use search tree to allocate', maxUnits,
          'calories')
    val, taken = maxVal(foods, maxUnits)
    print('Total costs of foods taken =', val)
    if printItems:
        for item in taken:
            print('   ', item)

# %%
names = ['wine', 'beer', 'pizza', 'burger', 'fries','cola', 'apple', 'donut', 'cake']
values = [89,90,95,100,90,79,50,10]
calories = [123,154,258,354,365,150,95,195]
foods = buildMenu(names, values, calories)
testMaxVal(foods, 2400)
# Out:
# Use search tree to allocate 2400 calories
# Total costs of foods taken = 603
#     donut: <10, 195>
#     apple: <50, 95>
#     cola: <79, 150>
#     fries: <90, 365>
#     burger: <100, 354>
#     pizza: <95, 258>
#     beer: <90, 154>
#     wine: <89, 123>

# %% [markdown]
# #### Supplementary Activity:

# %% [markdown]
# * Choose a real-world problem that solves knapsacks problem
# * Use the greedy and brute force algorithm to solve knapsacks problem

# %% [markdown]
# problem: you are deciding to go camping and you are deciding what items to bring and what are the weights of the items to maximize the capacity of the bag

# %% [markdown]
# GREEDY

# %%
items = [
    ("Tent", 12, 15),
    ("Sleeping Bag", 8, 10),
    ("Food", 6, 9),
    ("Water", 5, 8),
    ("Flashlight", 3, 5),
    ("Stove", 7, 7),
    ("Jacket", 4, 6),
    ("First Aid Kit", 2, 4)
]

capacity = 30 

def greedy_knapsack(items, capacity):

    items_sorted = sorted(items, key=lambda item: item[2]/item[1], reverse=True)

    total_weight = 0
    total_value = 0
    chosen_items = []

    for name, weight, value in items_sorted:
        if total_weight + weight <= capacity:
            chosen_items.append(name)
            total_weight += weight
            total_value += value

    return chosen_items, total_weight, total_value

chosen, weight, value = greedy_knapsack(items, capacity)

print("Greedy Algorithm Result (Capacity 30):")
print("Items chosen:", chosen)
print("Total weight:", weight)
print("Total value:", value)
# Out:
# Greedy Algorithm Result (Capacity 30):
# Items chosen: ['First Aid Kit', 'Flashlight', 'Water', 'Food', 'Jacket', 'Sleeping Bag']
# Total weight: 28
# Total value: 42

# %% [markdown]
# BRUTE FORCE

# %%
from itertools import combinations

items = [
    ("Tent", 12, 15),
    ("Sleeping Bag", 8, 10),
    ("Food", 6, 9),
    ("Water", 5, 8),
    ("Flashlight", 3, 5),
    ("Stove", 7, 7),
    ("Jacket", 4, 6),
    ("First Aid Kit", 2, 4)
]

capacity = 30  

def brute_force_knapsack(items, capacity):
    best_value = 0
    best_weight = 0
    best_combination = []

    for r in range(1, len(items)+1):
        for combo in combinations(items, r):
            total_weight = sum(item[1] for item in combo)
            total_value = sum(item[2] for item in combo)
            if total_weight <= capacity and total_value > best_value:
                best_value = total_value
                best_weight = total_weight
                best_combination = [item[0] for item in combo]

    return best_combination, best_weight, best_value

chosen, weight, value = brute_force_knapsack(items, capacity)

print("Brute Force Algorithm Result (Capacity 30):")
print("Items chosen:", chosen)
print("Total weight:", weight)
print("Total value:", value)
# Out:
# Brute Force Algorithm Result (Capacity 30):
# Items chosen: ['Tent', 'Food', 'Water', 'Flashlight', 'Jacket']
# Total weight: 30
# Total value: 43

# %% [markdown]
# #### Conclusion:

# %% [markdown]
# So in this real life problem i used the camping problem. we see that the brute force maximze the capacity of the backpack and the item that was chosen is the most valuable when you are camping outside. This demonstrates that greedy can provide a good approximation quickly, but the brute force guarantees the most accurate and optimal solution when maximizing the value within the maximum capacity.
